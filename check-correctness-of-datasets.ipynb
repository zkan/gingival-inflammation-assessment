# %% [markdown]
# # Check Correctness of Datasets

# %%
import pandas as pd

# %%
df = pd.read_excel('original/ID1-20 with x-ray.xlsx')
df.head()

# %%
df[df.DX.str.lower().str.contains('gingivitis')]

# %%
df[df.DX.str.lower().str.contains('generalize')]
# Out:
#     ID       HN  x-ray                                                 DX
# 0    1  1894/56    NaN  Generalized mild to moderate chronic periodont...
# 2    3  3799/55    NaN         generalized moderate chronic periodontitis
# 3    4  1600/56    NaN         generalized modearte chronic periodontitis
# 4    5  1197/56    NaN         generalized modearte chronic periodontitis
# 5    6  2466/56    NaN  generalized mild to moderate chronic periodont...
# 6    7   528/60    NaN         generalized modearte chronic periodontitis
# 7    8  1957/59    NaN             generalized mild chronic periodontitis
# 9   10   972/59    NaN  generalized mild to moderate chronic periodont...
# 10  11  3180/59    NaN  generalized mild with localized severe chronic...
# 11  12  2380/48    NaN  generalized mild to moderate with localized se...
# 13  14  2530/59    NaN  generalized mild with localized severe chronic...
# 14  15  3030/59    NaN  generalized mild to moderate with localized se...
# ...

# %%
df = pd.read_excel('original/ID21-76+xray.xlsx')
df.head()

# %%
df[df.Diagnosis.str.lower().str.contains('gingivitis')]

# %%
df[df.Diagnosis.str.lower().str.contains('generalize')]
# Out:
#      ID       HN                                          Diagnosis  X-ray
# 0    21   678/59  generalized mild to moderate with localized se...    NaN
# 1    23  1731/59  generalized mild to moderate chronic periodont...    NaN
# 3    26  2596/59  generalized mild with localized moderate chron...    NaN
# 4    28  2017/55  generalized mild to moderate with localized se...    NaN
# 5    29  3767/59  generalized moderate with localized severe chr...    NaN
# 7    31  3741/59           generalized severe chronic periodontitis    NaN
# 9    34  2169/59  generalized mild to moderate with localized se...    NaN
# 11   36   931/60           generalized severe chronic periodontitis    NaN
# 12   38   206/60  generalized mild to moderate with localized se...    NaN
# 13   40   108/60  generalized mild with localized moderate chron...    NaN
# 14   42   797/59  generalized mild to moderate with localized se...    NaN
# ...

# %%
df = pd.read_excel('original/ID111-165.xlsx')
df.head()
# Out:
#     ID       HN                                          Diagnosis
# 0  111  2315/58  generalized mild to moderate with localized se...
# 1  112  3964/58      gingivitis associated with dental plaque only
# 2  113  2238/58      gingivitis associated with dental plaque only
# 3  114  2414/56  generalized mild to moderate with localized se...
# 4  115   261/56      gingivitis associated with dental plaque only

# %%
df.loc[df.ID == 158]
# Out:
#      ID       HN                             Diagnosis
# 28  158  2597/60  localized mild chronic periodontitis

# %%
df.loc[df.ID == 158, 'Diagnosis'] = 'generalized localized mild chronic periodontitis'

# %%
df.loc[df.ID == 158]
# Out:
#      ID       HN                                         Diagnosis
# 28  158  2597/60  generalized localized mild chronic periodontitis

# %%
df.loc[df.ID == 131]
# Out:
#      ID      HN                                          Diagnosis
# 14  131  208/58  genralized moderate with localized severe chro...

# %%
df.loc[df.ID == 131].Diagnosis.str.replace('genralized', 'generalized')
# Out:
# 14    generalized moderate with localized severe chr...
# Name: Diagnosis, dtype: object

# %%
df.loc[df.ID == 131]
# Out:
#      ID      HN                                          Diagnosis
# 14  131  208/58  genralized moderate with localized severe chro...

# %%
df[df.Diagnosis.str.lower().str.contains('gingivitis')]
# Out:
#      ID       HN                                      Diagnosis
# 1   112  3964/58  gingivitis associated with dental plaque only
# 2   113  2238/58  gingivitis associated with dental plaque only
# 4   115   261/56  gingivitis associated with dental plaque only
# 5   116  1227/56  gingivitis associated with dental plaque only
# 8   125  1692/56  gingivitis associated with dental plaque only
# 9   126  2458/56  gingivitis associated with dental plaque only
# 12  129  2296/58  gingivitis associated with dental plaque only
# 13  130  4062/58  gingivitis associated with dental plaque only
# 25  151   720/57  gingivitis associated with dental plaque only
# 27  157  4010/53  gingivitis associated with dental plaque only

# %%
df[df.Diagnosis.str.lower().str.contains('generalize')]
# Out:
#      ID       HN                                          Diagnosis
# 0   111  2315/58  generalized mild to moderate with localized se...
# 3   114  2414/56  generalized mild to moderate with localized se...
# 6   117  1023/56  generalized moderate with localized severe chr...
# 7   118  2556/56  generalized mild with localized severe chronic...
# 10  127   586/55  generalized mild to moderate with localized se...
# 11  128  2284/58  generalized mild to moderate with localized se...
# 15  132   969/56  generalized mild to moderate with localized se...
# 16  133  3810/58  generalized mild to moderate with localized se...
# 17  135  1892/58           generalized severe chronic periodontitis
# 18  136  2302/58           generalized severe chronic periodontitis
# 19  137   158/57  generalized mild with localized moderate chron...
# 20  138  1004/57  generalized mild with localized moderate chron...
# 21  139  2608/57  generalized mild to moderate with localized se...
# ...
